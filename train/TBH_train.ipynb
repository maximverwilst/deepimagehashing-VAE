# %%
import sys
from google.colab import drive
drive.mount('/content/gdrive')
sys.path.append("/content/gdrive/My Drive/Mastersthesis/TBH")
from train import tbh_train

# %%
tbh_train.train("cifar", 32, 512, 400)
# Out:
# check
# batch 99: train_hook 0.42852665796669237, actor 1453.6444091796875, critic 1.27341890335083, divergence 5.710680961608887, lambda 1.100000023841858
# batch 199: train_hook 0.4078395118470062, actor 1396.0606689453125, critic 1.2275357246398926, divergence 9.522123336791992, lambda 1.2100000381469727
# batch 299: train_hook 0.47593159583227235, actor 1346.242919921875, critic 1.110490083694458, divergence 14.632059097290039, lambda 1.3310000896453857
# batch 399: train_hook 0.45492367628025654, actor 1424.5682373046875, critic 1.0363794565200806, divergence 16.795408248901367, lambda 1.4641001224517822
# batch 499: train_hook 0.5173944644103801, actor 1370.1265869140625, critic 0.979329526424408, divergence 20.830875396728516, lambda 1.6105101108551025
# batch 599: train_hook 0.4599168962691249, actor 1321.5335693359375, critic 0.914121150970459, divergence 20.272172927856445, lambda 1.7715611457824707
# ...
